# %%
# ! pip install numpy
# ! pip install scikit-learn==1.2.0
# ! pip install matplotlib==3.7.2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
pit.style.use('seaborn-whitegrid')
import numpy as np
# Out:
# /var/folders/vn/gm_zx9496dv0xnw4qr8k6k7h0000gp/T/ipykernel_40137/2491348244.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   pit.style.use('seaborn-whitegrid')

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(100)
y = 2 * x + 10 + rng.rand(100)
pit.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit)

# %%
print("model slope",model.coef_)
print("model intercept",model.intercept_)
# Out:
# model slope [1.99732897]
# model intercept 10.497816976132503

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(100, 3)
y = 0.5 + np.dot(x,[1.5,-2.,1.])

model.fit(x,y)
print("model slope",model.coef_)
print("model intercept",model.intercept_)
# Out:
# model slope [ 1.5 -2.   1. ]
# model intercept 0.5000000000000201

# %%
from sklearn.preprocessing import PolynomialFeatures
x = np.array([2, 3, 4])
poly = PolynomialFeatures(4, include_bias=False)
poly.fit_transform(x[:, None])
# Out:
# array([[  2.,   4.,   8.,  16.],
#        [  3.,   9.,  27.,  81.],
#        [  4.,  16.,  64., 256.]])

# %%
from sklearn.pipeline import make_pipeline
poly_model = make_pipeline(PolynomialFeatures(9),
                           LinearRegression())

rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = np.sin(x) + 0.1 * rng.randn(50)

poly_model.fit(x[:, np.newaxis], y)
yfit = poly_model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit);
